# %% [markdown]
# ## Cryptocurrency clusters

# %%
import pandas as pd
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.decomposition import PCA

# %%
# Read crypto_data.csv into Pandas. 
df = pd.read_csv('crypto_data.csv')
df.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0         42    42 Coin    Scrypt       True   PoW/PoS     4.199995e+01
# 1        365    365Coin       X11       True   PoW/PoS              NaN
# 2        404    404Coin    Scrypt       True   PoW/PoS     1.055185e+09
# 3        611  SixEleven   SHA-256       True       PoW              NaN
# 4        808        808   SHA-256       True   PoW/PoS     0.000000e+00
#
#   TotalCoinSupply
# 0              42
# 1      2300000000
# 2       532000000
# 3          611000
# 4               0

# %%
# Keep only cryptocurrencies that are trading
df = df.loc[df['IsTrading'] == True]

# %%
# drop the IsTrading column from the dataframe.
df.drop('IsTrading', axis=1, inplace=True)
# drop the CoinName column from the dataframe
# df.drop('CoinName', axis=1, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace = True)
df.head()
# Out:
#     CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 1    365Coin       X11   PoW/PoS              NaN      2300000000
# 2    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 3  SixEleven   SHA-256       PoW              NaN          611000
# 4        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Remove all rows that have at least one null value.
df = df.dropna(how='any',axis=0)
df.head()
# Out:
#     CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 4        808   SHA-256   PoW/PoS     0.000000e+00               0
# 5  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7    Bitcoin   SHA-256       PoW     1.792718e+07        21000000

# %%
# Filter for cryptocurrencies that have been mined. That is, the total coins mined should be greater than zero.
# mined_df = df.query('TotalCoinsMined > 0')
df = df.loc[df.TotalCoinsMined > 0]
df.head()
# Out:
#     CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 2    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5  EliteCoin       X13   PoW/PoS     2.927942e+10    314159265359
# 7    Bitcoin   SHA-256       PoW     1.792718e+07        21000000
# 8   Ethereum    Ethash       PoW     1.076842e+08               0

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from df 
coinname_df = pd.DataFrame(
    data = df, columns = ['CoinName'])
coinname_df.head()
# Out:
#     CoinName
# 0    42 Coin
# 2    404Coin
# 5  EliteCoin
# 7    Bitcoin
# 8   Ethereum

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
df = df.drop(columns = 'CoinName')
df.head()
# Out:
#   Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0    Scrypt   PoW/PoS     4.199995e+01              42
# 2    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       X13   PoW/PoS     2.927942e+10    314159265359
# 7   SHA-256       PoW     1.792718e+07        21000000
# 8    Ethash       PoW     1.076842e+08               0

# %%
# convert the remaining features with text values, Algorithm and ProofType, into numerical data. 
category_columns = ['Algorithm','ProofType']
df = pd.get_dummies(df, columns = category_columns)
df.head()
# Out:
#    TotalCoinsMined TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0     4.199995e+01              42                                 0
# 2     1.055185e+09       532000000                                 0
# 5     2.927942e+10    314159265359                                 0
# 7     1.792718e+07        21000000                                 0
# 8     1.076842e+08               0                                 0
#
#    Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0              0                  0                   0                0
# 2              0                  0                   0                0
# 5              0                  0                   0                0
# 7              0                  0                   0                0
# 8              0                  0                   0                0
#
#    Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 0                  0                  0              0  ...
# 2                  0                  0              0  ...
# 5                  0                  0              0  ...
# 7                  0                  0              0  ...
# 8                  0                  0              0  ...
#
#    ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 0                  1                   0                  0
# 2                  1                   0                  0
# 5                  1                   0                  0
# 7                  0                   0                  0
# 8                  0                   0                  0
#
#    ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 0                   0              0                             0
# 2                   0              0                             0
# 5                   0              0                             0
# 7                   0              0                             0
# 8                   0              0                             0
#
#    ProofType_Proof of Trust  ProofType_TPoS  ProofType_Zero-Knowledge Proof  \
# 0                         0               0                               0
# 2                         0               0                               0
# 5                         0               0                               0
# 7                         0               0                               0
# 8                         0               0                               0
#
#    ProofType_dPoW/PoW
# 0                   0
# 2                   0
# 5                   0
# 7                   0
# 8                   0
#
# [5 rows x 98 columns]

# %%
# Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.
# Scale the data

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)
print(scaled_data)
# Out:
# [[-0.11710817 -0.1528703  -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.09396955 -0.145009   -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [ 0.52494561  4.48942416 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  ...
#  [-0.09561336 -0.13217937 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11694817 -0.15255998 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]
#  [-0.11710536 -0.15285552 -0.0433963  ... -0.0433963  -0.0433963
#   -0.0433963 ]]

# %%
scaled_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-580c212815e7> in <module>()
# ----> 1 scaled_data.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
print(df.shape)
# Out:
# (577, 101)

# %%
# print(df.describe())

# %%
# df.hist()

# %%
pyplot.show()

# %% [markdown]
# # Dimensionality Reduction

# %%
# Perform dimensionality reduction with PCA
pca = PCA(n_components=3)
pca_data = pca.fit_transform(scaled_data)

# %%
# reduce the dataset dimensions with t-SNE and visually inspect the results.

# %% [markdown]
# # To put into my da class notes notebook

# %%
# remove all null values 
for column in df.columns:
    print(f"column {column} has {df[column].isnull().sum()} null values")
# Out:
# column TotalCoinsMined has 0 null values
# column TotalCoinSupply has 0 null values
# column Algorithm_1GB AES Pattern Search has 0 null values
# column Algorithm_536 has 0 null values
# column Algorithm_Argon2d has 0 null values
# column Algorithm_BLAKE256 has 0 null values
# column Algorithm_Blake has 0 null values
# column Algorithm_Blake2S has 0 null values
# column Algorithm_Blake2b has 0 null values
# column Algorithm_C11 has 0 null values
# column Algorithm_Cloverhash has 0 null values
# column Algorithm_Counterparty has 0 null values
# column Algorithm_CryptoNight has 0 null values
# column Algorithm_CryptoNight Heavy has 0 null values
# column Algorithm_CryptoNight-V7 has 0 null values
# column Algorithm_Cryptonight-GPU has 0 null values
# column Algorithm_DPoS has 0 null values
# column Algorithm_Dagger has 0 null values
# column Algorithm_Dagger-Hashimoto has 0 null values
# column Algorithm_ECC 256K1 has 0 null values
# column Algorithm_Equihash has 0 null values
# column Algorithm_Equihash+Scrypt has 0 null values
# column Algorithm_Ethash has 0 null values
# column Algorithm_Exosis has 0 null values
# column Algorithm_Green Protocol has 0 null values
# column Algorithm_Groestl has 0 null values
# column Algorithm_HMQ1725 has 0 null values
# column Algorithm_HybridScryptHash256 has 0 null values
# column Algorithm_IMesh has 0 null values
# column Algorithm_Jump Consistent Hash has 0 null values
# column Algorithm_Keccak has 0 null values
# column Algorithm_Leased POS has 0 null values
# column Algorithm_Lyra2RE has 0 null values
# column Algorithm_Lyra2REv2 has 0 null values
# column Algorithm_Lyra2Z has 0 null values
# column Algorithm_M7 POW has 0 null values
# column Algorithm_Multiple has 0 null values
# column Algorithm_NIST5 has 0 null values
# column Algorithm_NeoScrypt has 0 null values
# column Algorithm_Ouroboros has 0 null values
# column Algorithm_PHI1612 has 0 null values
# column Algorithm_POS 2.0 has 0 null values
# column Algorithm_POS 3.0 has 0 null values
# column Algorithm_PoS has 0 null values
# column Algorithm_Proof-of-Authority has 0 null values
# column Algorithm_Proof-of-BibleHash has 0 null values
# column Algorithm_QUAIT has 0 null values
# column Algorithm_QuBit has 0 null values
# column Algorithm_Quark has 0 null values
# column Algorithm_SHA-256 has 0 null values
# column Algorithm_SHA-256 + Hive has 0 null values
# column Algorithm_SHA-256D has 0 null values
# column Algorithm_SHA-512 has 0 null values
# column Algorithm_SHA3 has 0 null values
# column Algorithm_Scrypt has 0 null values
# column Algorithm_Semux BFT consensus has 0 null values
# column Algorithm_Shabal256 has 0 null values
# column Algorithm_Skein has 0 null values
# column Algorithm_SkunkHash has 0 null values
# column Algorithm_SkunkHash v2 Raptor has 0 null values
# column Algorithm_Stanford Folding has 0 null values
# column Algorithm_TRC10 has 0 null values
# column Algorithm_Time Travel has 0 null values
# column Algorithm_Tribus has 0 null values
# column Algorithm_VBFT has 0 null values
# column Algorithm_VeChainThor Authority has 0 null values
# column Algorithm_X11 has 0 null values
# column Algorithm_X11GOST has 0 null values
# column Algorithm_X13 has 0 null values
# column Algorithm_X14 has 0 null values
# column Algorithm_X15 has 0 null values
# column Algorithm_X16R has 0 null values
# column Algorithm_XEVAN has 0 null values
# column ProofType_DPOS has 0 null values
# column ProofType_DPoS has 0 null values
# column ProofType_HPoW has 0 null values
# column ProofType_LPoS has 0 null values
# column ProofType_POBh has 0 null values
# column ProofType_PoA has 0 null values
# column ProofType_PoC has 0 null values
# column ProofType_PoS has 0 null values
# column ProofType_PoS/LPoS has 0 null values
# column ProofType_PoS/PoW has 0 null values
# column ProofType_PoS/PoW/PoT has 0 null values
# column ProofType_PoST has 0 null values
# column ProofType_PoW has 0 null values
# column ProofType_PoW + Hive has 0 null values
# column ProofType_PoW and PoS has 0 null values
# column ProofType_PoW/PoS has 0 null values
# column ProofType_PoW/PoS  has 0 null values
# column ProofType_PoW/PoW has 0 null values
# column ProofType_PoW/nPoS has 0 null values
# column ProofType_Pos has 0 null values
# column ProofType_Proof of Authority has 0 null values
# column ProofType_Proof of Trust has 0 null values
# column ProofType_TPoS has 0 null values
# column ProofType_Zero-Knowledge Proof has 0 null values
# column ProofType_dPoW/PoW has 0 null values

# %%
# remove duplicate entries
print(f"duplicate entries: {df.duplicated().sum()}")
# Out:
# duplicate entries: 1

# %%
# change column data from yes / no to 1/0
def changestatus(status):
    if status == "Yes":
        return 1
    else
        return 0
# Out:
#   File "<ipython-input-79-4557f22dc846>", line 5
#     else
#         ^
# SyntaxError: invalid syntax

# %%
df_shopping["Previous Shopper"] = df_shopping["Previous Shopper"].apply(changestatus)
df_shopping.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-589000fd125c> in <module>()
# ----> 1 df_shopping["Previous Shopper"] = df_shopping["Previous Shopper"].apply(changestatus)
#       2 df_shopping.head()
#
# NameError: name 'df_shopping' is not defined

# %%
yes_no = ("Yes":1, "No":0)
# Out:
#   File "<ipython-input-82-0ca428676184>", line 1
#     yes_no = ("Yes":1, "No":0)
#                    ^
# SyntaxError: invalid syntax

# %%
# use map 
df_shopping["Previous Shopper"] = df_shopping["Previous Shopper"].map(yes_no)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-355cafa97dce> in <module>()
#       1 # use map
# ----> 2 df_shopping["Previous Shopper"] = df_shopping["Previous Shopper"].map(yes_no)
#
# NameError: name 'df_shopping' is not defined

# %%
# rename columns in data frame
new_df = new_df.rename(columns = {'Spending score (1-100)': 'Spending_Score'})
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-4e3a07b175f4> in <module>()
#       1 # rename columns in data frame
# ----> 2 new_df = new_df.rename(columns = {'Spending score (1-100)': 'Spending_Score'})
#       3 new_df.head()
#
# NameError: name 'new_df' is not defined

# %%
# save the cleaned data to a .csv 
new_df.to_csv(file_path, index=False)
